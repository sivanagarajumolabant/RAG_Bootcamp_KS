# %% [markdown]
# # 📊 How to Build a Knowledge Graph with FalkorDB & Graphiti
#
# **Overview:**
# - 🧠 Build knowledge graphs from structured + unstructured data
# - ⚽ Case study: Football/Soccer data knowledge graph
# - 🚀 Powered by Zep's [Graphiti](https://zep.dev) and [FalkorDB](https://www.falkordb.com/)
#
# ---

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this workshop, you'll know how to:
#
# 1. **🔄 Data Transformation**: Convert structured & unstructured data into graph form
# 2. **⚙️ Automation**: Automate data ingestion using Graphiti's pipelines
# 3. **🔍 Smart Retrieval**: Enable semantic search & question retrieval from graphs
# 4. **📈 Real-time Updates**: Keep your knowledge graph current with new information
#
# ---

# %% [markdown]
# ### Configure
#
#
# - 'FALKORDB_HOST' -
# - 'FALKORDB_PORT' - 57017
# - 'FALKORDB_USERNAME' - falkordb
# - 'FALKORDB_PASSWORD' - admin12345

# %%
from google.colab import userdata
userdata.get('FALKORDB_HOST')
# Out:
# 'r-6jissuruar.instance-g3qc7m2op.hc-2uaqqpjgg.us-east-2.aws.f2e0a955bb84.cloud:62211'

# %%
r-6jissuruar.instance-g3qc7m2op.hc-2uaqqpjgg.us-east-2.aws.f2e0a955bb84.cloud:62211

# %% [markdown]
# ## 🛠️ Setup & Installation
#
# First, let's install the required dependencies:

# %%
# Install Graphiti with FalkorDB support
# !pip install graphiti-core[falkordb]==v0.17.7
# Out:
# Collecting graphiti-core==v0.17.7 (from graphiti-core[falkordb]==v0.17.7)
#   Downloading graphiti_core-0.17.7-py3-none-any.whl.metadata (23 kB)
# Collecting diskcache>=5.6.3 (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting neo4j>=5.26.0 (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7)
#   Downloading neo4j-6.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2.0.2)
# Requirement already satisfied: openai>=1.91.0 in /usr/local/lib/python3.12/dist-packages (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2.24.0)
# Collecting posthog>=3.0.0 (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7)
#   Downloading posthog-7.9.7-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pydantic>=2.11.5 in /usr/local/lib/python3.12/dist-packages (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2.12.3)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (1.2.1)
# Requirement already satisfied: tenacity>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (9.1.4)
# Collecting falkordb<2.0.0,>=1.1.2 (from graphiti-core[falkordb]==v0.17.7)
#   Downloading falkordb-1.6.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from falkordb<2.0.0,>=1.1.2->graphiti-core[falkordb]==v0.17.7) (2.9.0.post0)
# Collecting redis>=7.1.0 (from falkordb<2.0.0,>=1.1.2->graphiti-core[falkordb]==v0.17.7)
#   Downloading redis-7.3.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from neo4j>=5.26.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2025.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (4.15.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (1.17.0)
# Collecting backoff>=1.10.0 (from posthog>=3.0.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.5->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.5->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.5->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.91.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0.0->graphiti-core==v0.17.7->graphiti-core[falkordb]==v0.17.7) (2.5.0)
# Downloading graphiti_core-0.17.7-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 9.6 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.1 MB/s eta 0:00:00
# Downloading falkordb-1.6.0-py3-none-any.whl (37 kB)
# Downloading neo4j-6.1.0-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 23.8 MB/s eta 0:00:00
# Downloading posthog-7.9.7-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 17.6 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading redis-7.3.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 29.9 MB/s eta 0:00:00
# Installing collected packages: redis, neo4j, diskcache, backoff, posthog, falkordb, graphiti-core
# Successfully installed backoff-2.2.1 diskcache-5.6.3 falkordb-1.6.0 graphiti-core-0.17.7 neo4j-6.1.0 posthog-7.9.7 redis-7.3.0

# %% [markdown]
# ## 📦 Import Libraries & Setup Environment
#
# Let's import all necessary libraries and set up our environment:

# %%
import os
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
from google.colab import userdata
from graphiti_core import Graphiti
from datetime import datetime, timezone
from graphiti_core.nodes import EpisodeType
from graphiti_core.driver.falkordb_driver import FalkorDriver
from graphiti_core.search.search_config_recipes import NODE_HYBRID_SEARCH_RRF

# Configuration
os.environ["MODEL_NAME"] = "gpt-4.1"
group_id = "la-liga"

# %% [markdown]
# ## 🔧 Helper Functions
#
# Let's define utility functions for data processing and graph operations:

# %%
async def add_episodes_to_graph(graphiti, episodes, group_id, prefix="Episode"):
    """Add a list of episodes to the graph using Graphiti."""
    print(f"📝 Adding {len(episodes)} episodes to graph...")

    for i, episode in enumerate(episodes):
        name = episode.get('name', f"{prefix} {i+1}")
        content = episode['content']

        # Convert non-string content to JSON
        if not isinstance(content, str):
            content = json.dumps(content)

        # Graphiti method for addin data
        await graphiti.add_episode(
            name=name,
            episode_body=content,
            source=episode['type'],
            source_description=episode['description'],
            reference_time=datetime.now(timezone.utc),
            group_id=group_id
        )

    print(f"✅ Successfully added {len(episodes)} episodes!")


def get_standing_table(url, teams_filter, date):
    """Extract La Liga standings from Wikipedia."""
    print(f"🏆 Fetching standings data for {date}...")

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    response = requests.get(url, headers=headers)
    response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)
    standing_table = pd.read_html(response.text)[5]

    # Clean and rename columns
    standing_table = standing_table.rename(columns={
        "Teamvte": "TeamName",
        "Pts": "Season Points",
        "Pos": "Season Position",
        "W": "Season Wins"
    })

    standing_table = standing_table[["TeamName", "Season Points", "Season Position", "Season Wins"]]

    # Clean team names (remove champion indicator)
    if not standing_table.empty and " (C)" in standing_table.at[0, "TeamName"]:
        standing_table.at[0, "TeamName"] = standing_table.at[0, "TeamName"].replace(" (C)", "")
    standing_table['Relevant Period'] = date

    episodes = []
    for row in standing_table.to_dict(orient="records"):
        if row["TeamName"] in teams_filter:
            episode = {
                "content": row,
                "type": EpisodeType.json,
                "description": f"Extract the {date} La Liga Standing into entities"
            }
            episodes.append(episode)

    print(f"✅ Found {len(episodes)} relevant team standings")
    return episodes


def get_topscorers_table(url, teams_filter, date):
    """Extract top scorers data from Wikipedia."""
    print(f"⚽ Fetching top scorers data for {date}...")

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    response = requests.get(url, headers=headers)
    response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)
    top_soccer_table = pd.read_html(response.text)[7]
    top_soccer_table = top_soccer_table.rename(columns={
        "Goals[51]": "Season Goals"})

    top_soccer_table['Seasion'] = date

    episodes = []
    for row in top_soccer_table.to_dict(orient="records"):
        if row["Club"] in teams_filter:
            episode = {
                "content": row,
                "type": EpisodeType.json,
                "description": f"Extract the {date} La Liga top player stats into different entities"
            }
            episodes.append(episode)

    print(f"✅ Found {len(episodes)} relevant top scorers")
    return episodes


def get_article_from_url(url):
    """Scrape article content from a URL."""
    print(f"📰 Fetching article from: {url}")

    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract date
    date_meta = soup.find("meta", {"name": "DC.date.issued"})
    article_date = date_meta["content"] if date_meta and date_meta.get("content") else "Date not found"

    # Extract article text
    paragraphs = soup.find_all("p")
    filtered = [p.get_text(strip=True) for p in paragraphs if len(p.get_text(strip=True)) > 50]
    article_text = "\n\n".join(filtered).encode("utf-8", "ignore").decode("utf-8")
    article_text = article_text.replace("í", "i")

    print("✅ Article extracted successfully")
    return article_date, article_text


async def search_and_display(graphiti, query, num_results=5):
    """Search the graph and display results in a clean format."""
    print(f"🔍 Searching for: '{query}'")
    print("-" * 50)

    results = await graphiti.search(query, num_results=num_results)

    for i, r in enumerate(results, 1):
        print(f"{i}. {r.fact}")
        print(f"   Label: {r.name}")
        print(f"   📅 Valid from: {r.valid_at}")
        if r.invalid_at:
            print(f"   ❌ Invalid at: {r.invalid_at}")
        print()

    return results

# %% [markdown]
# ## 🚀 Initialize Database Connection
#
# Now let's connect to FalkorDB and initialize our Graphiti instance:

# %%
# Set up API keys and database connection
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Initialize FalkorDB driver
falkor_driver = FalkorDriver(
    host="r-6jissuruar.instance-g3qc7m2op.hc-2uaqqpjgg.us-east-2.aws.f2e0a955bb84.cloud",
    port="62211",
    username=userdata.get('FALKORDB_USERNAME'),
    password=userdata.get('FALKORDB_PASSWORD'),
    database=group_id
)

# Initialize Graphiti
graphiti = Graphiti(graph_driver=falkor_driver)

# Build necessary indices and constraints
await graphiti.build_indices_and_constraints()

# %% [markdown]
# ## 📊 Part 1: Structured Data - La Liga Standings
#
# Let's start by ingesting structured data from Wikipedia about La Liga standings:
#
# La Liga Standings (2023/24)

# %%
# Configuration for our data extraction
standing_2324_url = 'https://en.wikipedia.org/wiki/2023%E2%80%9324_La_Liga'
TARGET_TEAMS = {"Real Madrid", "Barcelona"}  # Focus on El Clasico teams
relevant_date = '2023-07-25-2024-05-25'

# Extract standings data
episodes_2324 = get_standing_table(standing_2324_url, TARGET_TEAMS, relevant_date)

# Display what we extracted
print("\n📋 2023/24 Season Data:")
for episode in episodes_2324:
    content = episode['content']
    print(f"Team: {content['TeamName']}, Points: {content['Season Points']}, Position: {content['Season Position']}")

# Add 2023/24 standings to the graph
await add_episodes_to_graph(graphiti, episodes_2324, group_id, prefix="LaLiga 23/24 Standings")
# Out:
# 🏆 Fetching standings data for 2023-07-25-2024-05-25...
# ✅ Found 2 relevant team standings
#
# 📋 2023/24 Season Data:
# Team: Real Madrid, Points: 95, Position: 1
# Team: Barcelona, Points: 85, Position: 2
# 📝 Adding 2 episodes to graph...
# /tmp/ipykernel_799/51525797.py:33: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   standing_table = pd.read_html(response.text)[5]
# ✅ Successfully added 2 episodes!

# %%
episodes_2324
# Out:
# [{'content': {'TeamName': 'Real Madrid',
#    'Season Points': '95',
#    'Season Position': 1,
#    'Season Wins': 29,
#    'Relevant Period': '2023-07-25-2024-05-25'},
#   'type': <EpisodeType.json: 'json'>,
#   'description': 'Extract the 2023-07-25-2024-05-25 La Liga Standing into entities'},
#  {'content': {'TeamName': 'Barcelona',
#    'Season Points': '85',
#    'Season Position': 2,
#    'Season Wins': 26,
#    'Relevant Period': '2023-07-25-2024-05-25'},
#   'type': <EpisodeType.json: 'json'>,
#   'description': 'Extract the 2023-07-25-2024-05-25 La Liga Standing into entities'}]

# %% [markdown]
# Now let's add the current season data:
#
# La Liga Standings (2024/25)

# %%
standing_2425_url = 'https://en.wikipedia.org/wiki/2024%E2%80%9325_La_Liga'
relevant_date = '2024-07-25-2025-05-25'

# Extract current season standings
episodes_2425 = get_standing_table(standing_2425_url, TARGET_TEAMS, relevant_date)

# Display current season data
print("\n📋 2024/25 Season Data:")
for episode in episodes_2425:
    content = episode['content']
    print(f"Team: {content['TeamName']}, Points: {content['Season Points']}, Position: {content['Season Position']}")

# Add to graph
await add_episodes_to_graph(graphiti, episodes_2425, group_id, prefix="LaLiga 24/25 Standings")
# Out:
# 🏆 Fetching standings data for 2024-07-25-2025-05-25...
# ✅ Found 2 relevant team standings
#
# 📋 2024/25 Season Data:
# Team: Barcelona, Points: 88, Position: 1
# Team: Real Madrid, Points: 84, Position: 2
# 📝 Adding 2 episodes to graph...
# /tmp/ipykernel_799/51525797.py:33: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   standing_table = pd.read_html(response.text)[5]
# ✅ Successfully added 2 episodes!

# %% [markdown]
# ## ⚽ Part 2: Player Performance Data - Top Scorers
#
# Let's also add player performance data:

# %%
# Extract top scorers data
top_scorers_url = 'https://en.wikipedia.org/wiki/2024%E2%80%9325_La_Liga'
relevant_date = 'Season 24/25'

episodes_scorers = get_topscorers_table(top_scorers_url, TARGET_TEAMS, relevant_date)

# Add top scorers to graph
await add_episodes_to_graph(graphiti, episodes_scorers, group_id, prefix="LaLiga 24/25 Top Scorers")
# Out:
# ⚽ Fetching top scorers data for Season 24/25...
# ✅ Found 3 relevant top scorers
# 📝 Adding 3 episodes to graph...
# /tmp/ipykernel_799/51525797.py:71: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   top_soccer_table = pd.read_html(response.text)[7]
# WARNING:graphiti_core.llm_client.openai_base_client:Retrying after application error (attempt 1/2): Output length exceeded max tokens 8192: Could not parse response content as the length limit was reached - CompletionUsage(completion_tokens=8192, prompt_tokens=1685, total_tokens=9877, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# ✅ Successfully added 3 episodes!

# %% [markdown]
# ## 🔍 Graph-Based Query #1
#
# Let's test our knowledge graph with some queries:

# %%
# Query about Real Madrid's performance
fact_results = await search_and_display(graphiti, "What was Real Madrid’s final points at the end of each season?")
# Out:
# 🔍 Searching for: 'What was Real Madrid’s final points at the end of each season?'
# --------------------------------------------------
# 1. Real Madrid had 95 season points in the period 2023-07-25 to 2024-05-25.
#    Label: HAS_SEASON_POINTS
#    📅 Valid from: 2023-07-25 00:00:00+00:00
#    ❌ Invalid at: 2024-05-25 00:00:00+00:00
#
# 2. Real Madrid has 84 season points in the 2024-07-25 to 2025-05-25 period.
#    Label: HAS_SEASON_POINTS
#    📅 Valid from: 2026-03-07 07:16:07+00:00
#
# 3. Real Madrid had season position 1 in the period 2023-07-25 to 2024-05-25.
#    Label: HAS_SEASON_POSITION
#    📅 Valid from: 2023-07-25 00:00:00+00:00
#    ❌ Invalid at: 2024-05-25 00:00:00+00:00
#
# 4. Real Madrid had 29 season wins in the period 2023-07-25 to 2024-05-25.
#    Label: HAS_SEASON_WINS
#    📅 Valid from: 2023-07-25 00:00:00+00:00
#    ❌ Invalid at: 2024-05-25 00:00:00+00:00
#
# 5. Real Madrid has 26 season wins in the 2024-07-25 to 2025-05-25 period.
#    Label: HAS_SEASON_WINS
#    📅 Valid from: 2026-03-07 07:16:07+00:00

# %% [markdown]
# ## 📰 Part 3: Unstructured Data - News Article
#
# Now let's add some unstructured data from news articles:

# %%
# Scrape a football news article
article_url = "https://www.espn.com/soccer/story/_/id/45783151/marcus-rashford-arrives-barcelona-loan-man-united"
article_date, article_text = get_article_from_url(article_url)

# Create episode from article
espn_episode = {
    'content': f"{article_date}\n\n{article_text}",
    'type': EpisodeType.text,
    'description': "Football transfer news and rumors"
}
print("\n📰 Article Preview:")
print(article_text[:800] + "...\n")

# Add article to graph
await add_episodes_to_graph(graphiti, [espn_episode], group_id, prefix="ESPN Transfer News")
# Out:
# 📰 Fetching article from: https://www.espn.com/soccer/story/_/id/45783151/marcus-rashford-arrives-barcelona-loan-man-united
# ✅ Article extracted successfully
#
# 📰 Article Preview:
# Mark Ogden discusses Marcus Rashford's potential move to Barcelona after the Spanish club were given permission to speak to the player. (2:01)
#
# Marcus Rashfordlanded inBarcelonaon Sunday ahead of completing a season-long loan move fromManchester United.
#
# Rashford, 27, will undergo a medical early in the week and, if everything goes to plan, will be presented as a Barça player before the club head off on tour, a source told ESPN.
#
# Barça fly to Asia on Thursday and coach Hansi Flick was keen to have Rashford with the team in Japan and South Korea to give him as much time as possible to bed in before the season starts in August.
#
# - Sources:Rashford close to Barcelona loan move-Nico Williams explains 10-year Athletic extension- Sources:Man Utd close on Mbeumo before U.S. tour
#
# Rashford was cle...
#
# 📝 Adding 1 episodes to graph...
# ✅ Successfully added 1 episodes!

# %% [markdown]
# ## 🔍 Graph-Based Query #2
#
# Let's query about transfer rumors:

# %%
# Query about Barcelona transfer rumors
fact_results = await search_and_display(graphiti, "Who are the players rumored to move to Barcelona?")
# Out:
# 🔍 Searching for: 'Who are the players rumored to move to Barcelona?'
# --------------------------------------------------
# 1. Mark Ogden discusses Marcus Rashford's potential move to Barcelona after the Spanish club were given permission to speak to the player.
#    Label: DISCUSSES_POTENTIAL_MOVE_TO
#    📅 Valid from: 2025-07-20 20:37:00+00:00
#
# 2. Robert Lewandowski plays for Barcelona.
#    Label: PLAYS_FOR
#    📅 Valid from: 2026-03-07 07:21:34+00:00
#
# 3. Marcus Rashford has always preferred a move to Barça after the possibility of such a transfer emerged in January.
#    Label: PREFERS_MOVE_TO
#    📅 Valid from: 2025-01-01 00:00:00+00:00
#
# 4. Barça had made signing a left winger their priority this summer, including Luis Diaz.
#    Label: MADE_SIGNING_PRIORITY
#    📅 Valid from: 2025-05-01 00:00:00+00:00
#
# 5. Barça had made signing a left winger their priority this summer, including Nico Williams.
#    Label: MADE_SIGNING_PRIORITY
#    📅 Valid from: 2025-05-01 00:00:00+00:00

# %% [markdown]
# ## 🎯 Node Search
#
# Graphiti also supports searching for specific entities (nodes) in the graph:

# %%
# Configure node search
node_search_config = NODE_HYBRID_SEARCH_RRF.model_copy(deep=True)
node_search_config.limit = 2

# Search for specific entity
node_search_results = await graphiti._search(
    query='Hansi Flick',
    config=node_search_config
)

print("🔍 Node Search Results:")
print("-" * 30)
for i, node in enumerate(node_search_results.nodes, 1):
    print(f"{i}. Name: {node.name}")
    print(f"   Summary: {node.summary[:200]}...")
    print()
# Out:
# 🔍 Node Search Results:
# ------------------------------
# 1. Name: Hansi Flick
#    Summary: Hansi Flick is a football coach who was keen to have Marcus Rashford join Barcelona in the upcoming season. The messages do not provide additional details about Hansi Flick's background or career, onl...
#
# 2. Name: Robert Lewandowski
#    Summary: Marcus Rashford, a 27-year-old English international footballer, has completed a season-long loan move from Manchester United to Barcelona. The transfer was facilitated after all paperwork was complet...

# %% [markdown]
# ## 🔍 Graph-Based Query #3
#
# Let's ask about Barcelona's recent performance:

# %%
# Query about Barcelona's wins
fact_results = await search_and_display(graphiti, "What the latest news about Manchester United")
# Out:
# 🔍 Searching for: 'What the latest news about Manchester United'
# --------------------------------------------------
# 1. Ruben Amorim is the coach of Manchester United.
#    Label: COACH_OF
#    📅 Valid from: 2026-03-07 07:32:05+00:00
#
# 2. Marcus Rashford spent the last two weeks training away from the first-team squad at Manchester United after being told by coach Ruben Amorim that he does not feature in his plans.
#    Label: TRAINED_AWAY_FROM_FIRST_TEAM_AT
#    📅 Valid from: 2025-07-06 00:00:00+00:00
#    ❌ Invalid at: 2025-07-20 00:00:00+00:00
#
# 3. Marcus Rashford last played for Manchester United against Viktoria Plzen in the Europa League last December.
#    Label: PLAYED_AGAINST
#    📅 Valid from: 2024-12-01 00:00:00+00:00
#
# 4. Mark Ogden discusses Marcus Rashford's potential move to Barcelona after the Spanish club were given permission to speak to the player.
#    Label: DISCUSSES_POTENTIAL_MOVE_TO
#    📅 Valid from: 2025-07-20 20:37:00+00:00
#
# 5. Marcus Rashford landed in Barcelona on Sunday ahead of completing a season-long loan move from Manchester United.
#    Label: LANDS_IN
#    📅 Valid from: 2025-07-20 00:00:00+00:00

# %% [markdown]
# ## 🔄 Part 4: Real-time Updates
#
# One of the key advantages of knowledge graphs is their ability to handle updates and maintain temporal consistency:

# %%
# Simulate new transfer updates
new_updates = [
    {
        "content": "Lionel Messi is rumored to be transferring to Barcelona from Inter Miami.",
        "type": EpisodeType.message,
        "description": "Latest transfer rumor update"
    },
    {
        "content": "Mark Ogden reports that Marcus Rashford has renewed his contract with Manchester United until 2028 and he is no longer connected to any move or loan to Barcelona anymore.",
        "type": EpisodeType.message,
        "description": "Previous facts updates - update the old facts"
    }
]

# Add updates to graph
await add_episodes_to_graph(graphiti, new_updates, group_id, prefix="Transfer Update")
# Out:
# 📝 Adding 2 episodes to graph...
# ✅ Successfully added 2 episodes!

# %% [markdown]
# ## 🔍 Updated Query Results
#
# Let's see how our graph handles the updated information:

# %%
# Query again about Barcelona transfers - should show updated information
fact_results = await search_and_display(graphiti, "Who are the players rumored to move to Barcelona?")
# Out:
# 🔍 Searching for: 'Who are the players rumored to move to Barcelona?'
# --------------------------------------------------
# 1. Lionel Messi is rumored to be transferring to Barcelona from Inter Miami.
#    Label: RUMORED_TO_TRANSFER_TO
#    📅 Valid from: 2026-02-28 22:43:37+00:00
#
# 2. Barcelona moved for Luis Diaz.
#    Label: SIGNED_PLAYER
#    📅 Valid from: 2025-07-20 20:37:00+00:00
#
# 3. Barcelona moved for Nico Williams.
#    Label: SIGNED_PLAYER
#    📅 Valid from: 2025-07-20 20:37:00+00:00
#
# 4. Mark Ogden discusses Marcus Rashford's potential move to Barcelona after the Spanish club were given permission to speak to the player.
#    Label: DISCUSSES_POTENTIAL_MOVE_TO
#    📅 Valid from: 2025-07-20 20:37:00+00:00
#
# 5. Marcus Rashford has always preferred a move to Barcelona after the possibility of such a transfer emerged in January.
#    Label: PREFERRED_MOVE_TO
#    📅 Valid from: 2025-01-01 00:00:00+00:00

# %%
fact_results = await search_and_display(graphiti, "What is the latest news about Manchester United?")
# Out:
# 🔍 Searching for: 'What is the latest news about Manchester United?'
# --------------------------------------------------
# 1. Ruben Amorim is the coach of Manchester United.
#    Label: COACH_OF
#    📅 Valid from: 2025-07-20 20:37:00+00:00
#
# 2. Mark Ogden reports that Marcus Rashford has renewed his contract with Manchester United until 2028.
#    Label: REPORTED_BY
#    📅 Valid from: 2026-02-28 22:43:42+00:00
#
# 3. Marcus Rashford spent the last two weeks training away from the first-team squad at Manchester United after being told by coach Ruben Amorim that he does not feature in his plans.
#    Label: TRAINED_AWAY_FROM_FIRST_TEAM_AT
#    📅 Valid from: 2025-07-06 00:00:00+00:00
#    ❌ Invalid at: 2025-07-20 00:00:00+00:00
#
# 4. Marcus Rashford last played for Manchester United against Viktoria Plzen in the Europa League last December.
#    Label: PLAYED_AGAINST
#    📅 Valid from: 2024-12-01 00:00:00+00:00
#    ❌ Invalid at: 2025-07-20 00:00:00+00:00
#
# 5. Manchester United and Barcelona completed all the necessary paperwork for Rashford's travel to Barcelona.
#    Label: COMPLETED_PAPERWORK_WITH
#    📅 Valid from: 2025-07-20 00:00:00+00:00

# %% [markdown]
# ## 🎬 Complex Queries
#
# Let's demonstrate the power of graph-based retrieval with complex queries:

# %%
from openai import OpenAI
from typing import Optional
from datetime import datetime

client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

class FactWithTime:
    def __init__(self, fact: str, valid_at: datetime, invalid_at: Optional[datetime]):
        self.fact = fact
        self.valid_at = valid_at
        self.invalid_at = invalid_at

def format_temporal_context(facts: list[FactWithTime]) -> str:
    lines = []
    for f in facts:
        line = f"- {f.fact.strip()} (valid from"
        if f.valid_at:
          line += f"{f.valid_at.strftime('%Y-%m-%d')}"
        else:
          line += "now"

        if f.invalid_at:
            line += f" to {f.invalid_at.strftime('%Y-%m-%d')}"
        else:
            line += ", still valid"
        line += ")"
        lines.append(line)
    return "\n".join(lines)

async def graphiti_agent(graphiti, query: str, num_results: int = 12, model: str = "gpt-4") -> str:
    print(f"🔍 Searching Graphiti for: '{query}'")
    results = await graphiti.search(query, num_results=num_results)

    facts = [
        FactWithTime(fact=r.fact, valid_at=r.valid_at, invalid_at=r.invalid_at)
        for r in results
    ]
    context = format_temporal_context(facts)
    system_prompt = (
    "You are Graphiti, an expert knowledge graph agent.\n"
    "You are given a list of facts, each with a date range indicating when it was valid.\n"
    "Some facts describe past events but may have been added or validated later.\n\n"
    "Your task is to answer the user's question using the facts that describe the relevant time period.\n"
    "The date when a fact became valid is not the same as the time it describes — for example, a fact added in 2025 can still describe the 2023/24 season.\n"
    "Therefore, use any fact that describes the relevant time period, even if the fact itself became valid later.\n\n"
    "If no fact describes the relevant time period, explain clearly why the available facts are insufficient to answer the question.\n"
    "Be transparent about missing or incomplete data if you can't fully answer.\n\n"
    "Respond with a **concise**, factual answer. Use bullet points if helpful, but avoid repeating the context or adding unnecessary commentary."
    )
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": f"Facts:\n{context}\n\nQuestion:\n{query.strip()}"}
        ],
        temperature=0.5,
        max_tokens=500
    )

    return response.choices[0].message.content.strip()

# %%
# 🎯 Complex Query Demo — requires reasoning across multiple facts
print("🎯 Complex Query Demo")
print("=" * 50)

queries = [
    "Compare Real Madrid and Barcelona performance between the 2023/24 and 2024/25 seasons.",
    "Where does the player with the most goals currently play?",
    "How many points was to the club that Messi rumored to",
]

for query in queries:
    try:
        answer = await graphiti_agent(graphiti, query)
        print("✅ Answer:", answer)
    except Exception as e:
        print("❌ Error:", str(e))
    print("-" * 50)
# Out:
# 🎯 Complex Query Demo
# ==================================================
# 🔍 Searching Graphiti for: 'Compare Real Madrid and Barcelona performance between the 2023/24 and 2024/25 seasons.'
# ✅ Answer: **2023/24 Season:**
# - Real Madrid finished in 1st position with 95 season points and 29 season wins.
# - Barcelona finished in 2nd position with 85 season points and 26 season wins.
#
# **2024/25 Season:**
# - Real Madrid finished in 2nd position with 84 season points and 26 season wins.
# - Barcelona finished in 1st position with 88 season points and 28 season wins.
# --------------------------------------------------
# 🔍 Searching Graphiti for: 'Where does the player with the most goals currently play?'
# ✅ Answer: The player with the most goals, according to the available facts, is Kylian Mbappé who scored 31 goals in the 24/25 season. During that season, he played for Real Madrid.
# --------------------------------------------------
# 🔍 Searching Graphiti for: 'How many points was to the club that Messi rumored to'
# ✅ Answer: Lionel Messi is rumored to be transferring to Barcelona. During the latest available seasons, Barcelona had:
#
# - 85 season points in the 2023-07-25 to 2024-05-25 period
# - 88 season points in the 2024-07-25 to 2025-05-25 period
# --------------------------------------------------
