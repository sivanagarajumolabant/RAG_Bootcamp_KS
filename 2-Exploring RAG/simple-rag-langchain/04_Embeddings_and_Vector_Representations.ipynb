# %% [markdown]
# # 🔢 Notebook 04: Embeddings and Vector Representations
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ## 🎯 Objectives
# 1. Understand what embeddings are
# 2. Use OpenAI Embeddings
# 3. Use Google Gemini Embeddings
# 4. Compare embedding models
# 5. Calculate similarity between vectors

# %%
from dotenv import load_dotenv
import os
load_dotenv()
print("✅ Setup complete")
# Out:
# ✅ Setup complete

# %% [markdown]
# ## 1. What are Embeddings? 🤔
#
# ### 🔰 BEGINNER
#
# **Embeddings** convert text into numbers (vectors) that capture meaning.
#
# Think of it like a GPS coordinate:
# - "dog" → [0.2, 0.8, 0.1, ...] (1536 numbers)
# - "cat" → [0.3, 0.7, 0.2, ...] (close to "dog"!)
# - "car" → [0.9, 0.1, 0.8, ...] (far from "dog")
#
# Similar meanings = Similar vectors!

# %% [markdown]
# ## 2. OpenAI Embeddings

# %%
from langchain_openai import OpenAIEmbeddings

# Initialize
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# Create embedding for a query
query = "What is machine learning?"
query_vector = embeddings.embed_query(query)

print(f"Query: {query}")
print(f"Vector dimensions: {len(query_vector)}")
print(f"First 5 values: {query_vector[:5]}")

# Embed multiple documents
docs = [
    "Machine learning is a subset of AI",
    "Deep learning uses neural networks",
    "The weather is sunny today"
]

doc_vectors = embeddings.embed_documents(docs)
print(f"\nEmbedded {len(doc_vectors)} documents")
# Out:
# Query: What is machine learning?
# Vector dimensions: 1536
# First 5 values: [-0.002476818859577179, -0.012755980715155602, -0.006645360495895147, -0.03157883137464523, 0.028759293258190155]
#
# Embedded 3 documents

# %% [markdown]
# ## 3. Google Gemini Embeddings

# %%
# !uv pip install langchain-google-genai
# Out:
# Resolved 39 packages in 907ms
# ⠙ Preparing packages... (0/9)
# ⠙ Preparing packages... (0/9)----     0 B/11.23 KiB
# ⠙ Preparing packages... (0/9) 11.23 KiB/11.23 KiB
# cachetools ------------------------------ 11.23 KiB/11.23 KiB
# ⠙ Preparing packages... (0/9)---------     0 B/169.63 KiB
# cachetools ------------------------------ 11.23 KiB/11.23 KiB
# google-api-core ------------------------------     0 B/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------     0 B/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 14.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 30.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 46.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 62.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# ⠙ Preparing packages... (0/9)----     0 B/417.50 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# grpcio-status ------------------------------ 14.09 KiB/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------ 16.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# google-api-core ------------------------------ 139.27 KiB/169.63 KiB
# google-auth ------------------------------ 80.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 78.42 KiB/290.54 KiB
# protobuf   ------------------------------ 64.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 64.00 KiB/1.34 MiB
# ⠙ Preparing packages... (0/9)---- 64.00 KiB/11.27 MiB
# google-api-core ------------------------------ 139.27 KiB/169.63 KiB
# google-auth ------------------------------ 80.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 78.42 KiB/290.54 KiB
# protobuf   ------------------------------ 64.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 64.00 KiB/1.34 MiB
# ⠙ Preparing packages... (0/9)---- 80.00 KiB/11.27 MiB
# google-auth ------------------------------ 112.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 110.32 KiB/290.54 KiB
# protobuf   ------------------------------ 128.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 112.00 KiB/1.34 MiB
# ⠙ Preparing packages... (0/9)---- 144.00 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 222.42 KiB/290.54 KiB
# protobuf   ------------------------------ 224.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 240.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 240.24 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 238.42 KiB/290.54 KiB
# protobuf   ------------------------------ 224.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 240.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 240.24 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 238.42 KiB/290.54 KiB
# protobuf   ------------------------------ 240.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 240.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 240.24 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 254.42 KiB/290.54 KiB
# protobuf   ------------------------------ 255.89 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 272.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 272.00 KiB/11.27 MiB
# protobuf   ------------------------------ 288.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 288.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 272.00 KiB/11.27 MiB
# protobuf   ------------------------------ 384.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 384.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 384.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 496.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 464.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 608.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 560.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 752.00 KiB/1.34 MiB
# ⠸ Preparing packages... (7/9)---- 704.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 1.05 MiB/1.34 MiB
# ⠸ Preparing packages... (7/9)---- 1.05 MiB/11.27 MiB
# ⠸ Preparing packages... (7/9)---- 1.64 MiB/11.27 MiB
# ⠸ Preparing packages... (7/9)---- 1.86 MiB/11.27 MiB
# ⠸ Preparing packages... (7/9)---- 3.60 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 4.95 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 6.73 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 7.10 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 7.12 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 7.33 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 7.67 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 8.05 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 8.95 MiB/11.27 MiB
# Prepared 9 packages in 1.03s
# Installed 13 packages in 39ms
#  + cachetools==6.2.2
#  + google-ai-generativelanguage==0.9.0
#  + google-api-core==2.28.1
#  + google-auth==2.43.0
#  + googleapis-common-protos==1.72.0
#  + grpcio==1.76.0
#  + grpcio-status==1.76.0
#  + langchain-google-genai==3.0.3
#  + proto-plus==1.26.1
#  + protobuf==6.33.1
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + rsa==4.9.1

# %%
# Google Gemini Embeddings
if os.getenv("GOOGLE_API_KEY"):
    from langchain_google_genai import GoogleGenerativeAIEmbeddings
    
    gemini_embeddings = GoogleGenerativeAIEmbeddings(
        model="models/embedding-001"
    )
    
    vector = gemini_embeddings.embed_query("Hello world")
    print(f"Gemini vector dimensions: {len(vector)}")
else:
    print("⚠️ Google API key not found. Set GOOGLE_API_KEY in .env")
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/langchain_google_genai/embeddings.py:346, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     340     request: EmbedContentRequest = self._prepare_request(
#     341         text=text,
#     342         task_type=task_type_to_use,
#     343         title=title,
#     344         output_dimensionality=output_dimensionality,
#     345     )
# --> 346     result: EmbedContentResponse = self.client.embed_content(request)
#     347 except Exception as e:
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:1306, in GenerativeServiceClient.embed_content(self, request, model, content, retry, timeout, metadata)
#    1305 # Send the request.
# -> 1306 response = rpc(
#    1307     request,
#    1308     retry=retry,
#    1309     timeout=timeout,
#    1310     metadata=metadata,
#    1311 )
#    1313 # Done; return the response.
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/google/api_core/grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerUserPerProjectPerModel-FreeTier"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[6], line 9
#       3     from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       5     gemini_embeddings = GoogleGenerativeAIEmbeddings(
#       6         model="models/embedding-001"
#       7     )
# ----> 9     vector = gemini_embeddings.embed_query("Hello world")
#      10     print(f"Gemini vector dimensions: {len(vector)}")
#      11 else:
#
# File ~/Downloads/simple-rag-langchain/.venv/lib/python3.13/site-packages/langchain_google_genai/embeddings.py:349, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     347 except Exception as e:
#     348     msg = f"Error embedding content: {e}"
# --> 349     raise GoogleGenerativeAIError(msg) from e
#     350 return list(result.embedding.values)
#
# GoogleGenerativeAIError: Error embedding content: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerUserPerProjectPerModel-FreeTier"
# }
# ]

# %% [markdown]
# ## 4. Similarity Calculation

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    """Calculate cosine similarity between two vectors"""
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Test similarity
texts = [
    "I love programming",
    "I enjoy coding",
    "The weather is nice"
]

vectors = [embeddings.embed_query(text) for text in texts]

print("Similarity Scores:")
print(f"'{texts[0]}' vs '{texts[1]}': {cosine_similarity(vectors[0], vectors[1]):.4f}")
print(f"'{texts[0]}' vs '{texts[2]}': {cosine_similarity(vectors[0], vectors[2]):.4f}")
print("\nSimilar meanings = Higher similarity score!")
# Out:
# Similarity Scores:
# 'I love programming' vs 'I enjoy coding': 0.7529
# 'I love programming' vs 'The weather is nice': 0.2328
#
# Similar meanings = Higher similarity score!

# %% [markdown]
# ## Summary
#
# ✅ Embeddings convert text to vectors
# ✅ OpenAI text-embedding-3-small: 1536 dimensions
# ✅ Google Gemini: 768 dimensions
# ✅ Cosine similarity measures vector similarity
#
# **Next:** Vector Stores for efficient search!
