# %% [markdown]
# # 🗄️ Notebook 05: Vector Stores
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ## 🎯 Objectives
# 1. Understand vector stores
# 2. Use InMemoryVectorStore (testing)
# 3. Use FAISS (production)
# 4. Use Chroma (persistent)
# 5. Compare vector stores

# %%
from dotenv import load_dotenv
from pathlib import Path
load_dotenv()
print("✅ Setup complete")

# %% [markdown]
# ## 1. What are Vector Stores? 🤔
#
# ### 🔰 BEGINNER
#
# **Vector Stores** are databases optimized for finding similar vectors.
#
# Like a library:
# - Traditional database: "Find book with ISBN 12345"
# - Vector store: "Find books similar to this topic"
#
# They enable **semantic search**!

# %% [markdown]
# ## 2. InMemoryVectorStore (Simple)

# %%
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document

# Initialize
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = InMemoryVectorStore(embedding=embeddings)

# Add documents
docs = [
    Document(page_content="Python is a programming language"),
    Document(page_content="Machine learning uses algorithms"),
    Document(page_content="The sun is a star")
]

vector_store.add_documents(docs)
print(f"✅ Added {len(docs)} documents\n")

# Search
results = vector_store.similarity_search("What is Python?", k=2)

print("Search Results:")
for i, doc in enumerate(results, 1):
    print(f"{i}. {doc.page_content}")
# Out:
# ✅ Added 3 documents
#
# Search Results:
# 1. Python is a programming language
# 2. Machine learning uses algorithms

# %% [markdown]
# ## 3. FAISS (Fast & Production-Ready)

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# Load and split a PDF
pdf_path = "attention.pdf"

if Path(pdf_path).exists():
    print("Loading PDF...")
    loader = PyPDFLoader(pdf_path)
    documents = loader.load()
    
    # Split
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=200
    )
    chunks = splitter.split_documents(documents)
    print(f"Split into {len(chunks)} chunks")
    
    # Create FAISS vectorstore
    print("Creating embeddings (this may take a minute)...")
    vectorstore = FAISS.from_documents(chunks, embeddings)
    
    # Save to disk
    vectorstore.save_local("./faiss_index_notebook")
    print("✅ FAISS index saved\n")
    
    # Search
    query = "What is attention mechanism?"
    results = vectorstore.similarity_search(query, k=3)
    
    print(f"Query: {query}\n")
    for i, doc in enumerate(results, 1):
        print(f"Result {i}:")
        print(f"  {doc.page_content[:150]}...\n")
else:
    print(f"❌ PDF not found: {pdf_path}")
# Out:
# Loading PDF...
# Split into 52 chunks
# Creating embeddings (this may take a minute)...
# ✅ FAISS index saved
#
# Query: What is attention mechanism?
#
# Result 1:
#   Attention Visualizations
# Input-Input Layer5
# It
# is
# in
# this
# spirit
# that
# a
# majority
# of
# American
# governments
# have
# passed
# new
# laws
# since
# 2009
# making
# the
# re...
#
# Result 2:
#   3.2 Attention
# An attention function can be described as mapping a query and a set of key-value pairs to an output,
# where the query, keys, values, and ...
#
# Result 3:
#   Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalis...

# %% [markdown]
# ## 4. Loading Existing FAISS Index

# %%
# Load existing index
if Path("./faiss_index_notebook").exists():
    loaded_vectorstore = FAISS.load_local(
        "./faiss_index_notebook",
        embeddings,
        allow_dangerous_deserialization=True
    )
    print("✅ Loaded existing FAISS index")
    
    # Use it
    results = loaded_vectorstore.similarity_search("transformers", k=2)
    print(f"\nFound {len(results)} results")
else:
    print("No existing index found")
# Out:
# ✅ Loaded existing FAISS index
#
# Found 2 results

# %% [markdown]
# ## 5. Chroma (Persistent & Easy)

# %%
# !uv pip install langchain-chroma
# Out:
# Resolved 93 packages in 914ms
# ⠙ Preparing packages... (0/14)
# ⠙ Preparing packages... (0/14)------------     0 B/70.83 KiB
# ⠙ Preparing packages... (0/14)------------ 14.84 KiB/70.83 KiB
# opentelemetry-proto ------------------------------ 14.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)----------     0 B/129.25 KiB
# opentelemetry-proto ------------------------------ 14.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------     0 B/45.93 KiB
# opentelemetry-proto ------------------------------ 14.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-proto ------------------------------ 14.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-proto ------------------------------ 30.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-proto ------------------------------ 46.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-proto ------------------------------ 62.84 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# ⠙ Preparing packages... (0/14)---------- 14.84 KiB/129.25 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# ⠙ Preparing packages... (0/14)--------     0 B/503.50 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# ⠙ Preparing packages... (0/14)--------     0 B/503.50 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------     0 B/45.98 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# ⠙ Preparing packages... (0/14)--------     0 B/503.50 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------     0 B/45.98 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# huggingface-hub ------------------------------     0 B/503.50 KiB
# ⠙ Preparing packages... (0/14)---     0 B/2.60 MiB
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/17.93 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------     0 B/45.98 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# huggingface-hub ------------------------------     0 B/503.50 KiB
# ⠙ Preparing packages... (0/14)--     0 B/2.60 MiB
# langchain-chroma ------------------------------     0 B/12.17 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/17.93 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------     0 B/45.98 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# huggingface-hub ------------------------------     0 B/503.50 KiB
# ⠙ Preparing packages... (0/14)--     0 B/2.60 MiB
# langchain-chroma ------------------------------     0 B/12.17 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/17.93 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------     0 B/19.23 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------     0 B/45.98 KiB
# opentelemetry-api ------------------------------     0 B/64.40 KiB
# opentelemetry-proto ------------------------------ 70.83 KiB/70.83 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# huggingface-hub ------------------------------     0 B/503.50 KiB
# ⠙ Preparing packages... (0/14)--     0 B/2.60 MiB
# langchain-chroma ------------------------------     0 B/12.17 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/17.93 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------     0 B/19.23 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------     0 B/45.98 KiB
# opentelemetry-api ------------------------------ 14.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------     0 B/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------     0 B/203.08 KiB
# huggingface-hub ------------------------------     0 B/503.50 KiB
# hf-xet     ------------------------------     0 B/2.60 MiB
# onnxruntime ------------------------------     0 B/16.40 MiB
# ⠙ Preparing packages... (0/14)--     0 B/18.27 MiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 16.00 KiB/17.93 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/19.23 KiB
# typer      ------------------------------ 14.89 KiB/45.93 KiB
# typer-slim ------------------------------ 16.00 KiB/45.98 KiB
# opentelemetry-api ------------------------------ 14.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 14.84 KiB/129.25 KiB
# fsspec     ------------------------------ 14.88 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------  1009 B/203.08 KiB
# huggingface-hub ------------------------------ 16.00 KiB/503.50 KiB
# hf-xet     ------------------------------ 16.00 KiB/2.60 MiB
# onnxruntime ------------------------------     0 B/16.40 MiB
# ⠙ Preparing packages... (0/14)--     0 B/18.27 MiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 19.23 KiB/19.23 KiB
# typer      ------------------------------ 30.89 KiB/45.93 KiB
# typer-slim ------------------------------ 32.00 KiB/45.98 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 30.84 KiB/129.25 KiB
# fsspec     ------------------------------ 14.88 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 11.70 KiB/203.08 KiB
# huggingface-hub ------------------------------ 32.00 KiB/503.50 KiB
# hf-xet     ------------------------------ 32.00 KiB/2.60 MiB
# onnxruntime ------------------------------ 16.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)-- 16.00 KiB/18.27 MiB
# typer      ------------------------------ 30.89 KiB/45.93 KiB
# typer-slim ------------------------------ 32.00 KiB/45.98 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 30.84 KiB/129.25 KiB
# fsspec     ------------------------------ 14.88 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 11.70 KiB/203.08 KiB
# huggingface-hub ------------------------------ 32.00 KiB/503.50 KiB
# hf-xet     ------------------------------ 32.00 KiB/2.60 MiB
# onnxruntime ------------------------------ 16.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)-- 16.00 KiB/18.27 MiB
# typer      ------------------------------ 45.93 KiB/45.93 KiB
# typer-slim ------------------------------ 45.98 KiB/45.98 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 46.84 KiB/129.25 KiB
# fsspec     ------------------------------ 30.88 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 11.70 KiB/203.08 KiB
# huggingface-hub ------------------------------ 48.00 KiB/503.50 KiB
# hf-xet     ------------------------------ 32.00 KiB/2.60 MiB
# onnxruntime ------------------------------ 16.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)-- 32.00 KiB/18.27 MiB
# typer-slim ------------------------------ 45.98 KiB/45.98 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 46.84 KiB/129.25 KiB
# fsspec     ------------------------------ 30.88 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.56 KiB/203.08 KiB
# huggingface-hub ------------------------------ 48.00 KiB/503.50 KiB
# hf-xet     ------------------------------ 48.00 KiB/2.60 MiB
# onnxruntime ------------------------------ 16.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)-- 32.00 KiB/18.27 MiB
# opentelemetry-api ------------------------------ 30.88 KiB/64.40 KiB
# opentelemetry-sdk ------------------------------ 46.84 KiB/129.25 KiB
# fsspec     ------------------------------ 30.88 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.56 KiB/203.08 KiB
# huggingface-hub ------------------------------ 48.00 KiB/503.50 KiB
# hf-xet     ------------------------------ 48.00 KiB/2.60 MiB
# onnxruntime ------------------------------ 16.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)--- 32.00 KiB/18.27 MiB
# opentelemetry-sdk ------------------------------ 76.23 KiB/129.25 KiB
# fsspec     ------------------------------ 77.59 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 48.00 KiB/203.08 KiB
# huggingface-hub ------------------------------ 94.40 KiB/503.50 KiB
# hf-xet     ------------------------------ 94.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 80.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)--- 80.00 KiB/18.27 MiB
# fsspec     ------------------------------ 109.59 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 80.00 KiB/203.08 KiB
# huggingface-hub ------------------------------ 126.40 KiB/503.50 KiB
# hf-xet     ------------------------------ 126.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 112.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)--- 128.00 KiB/18.27 MiB
# fsspec     ------------------------------ 109.59 KiB/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------ 80.00 KiB/203.08 KiB
# huggingface-hub ------------------------------ 126.40 KiB/503.50 KiB
# hf-xet     ------------------------------ 126.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 128.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)--- 128.00 KiB/18.27 MiB
# opentelemetry-semantic-conventions ------------------------------ 144.00 KiB/203.08 KiB
# huggingface-hub ------------------------------ 190.40 KiB/503.50 KiB
# hf-xet     ------------------------------ 190.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 208.00 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)--- 208.00 KiB/18.27 MiB
# huggingface-hub ------------------------------ 254.40 KiB/503.50 KiB
# hf-xet     ------------------------------ 222.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 235.72 KiB/16.40 MiB
# ⠙ Preparing packages... (0/14)--- 240.00 KiB/18.27 MiB
# huggingface-hub ------------------------------ 302.29 KiB/503.50 KiB
# hf-xet     ------------------------------ 270.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 272.00 KiB/16.40 MiB
# ⠹ Preparing packages... (10/14)-- 288.00 KiB/18.27 MiB
# hf-xet     ------------------------------ 574.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 592.00 KiB/16.40 MiB
# ⠹ Preparing packages... (10/14)-- 495.44 KiB/18.27 MiB
# hf-xet     ------------------------------ 846.90 KiB/2.60 MiB
# onnxruntime ------------------------------ 864.00 KiB/16.40 MiB
# ⠹ Preparing packages... (10/14)-- 576.00 KiB/18.27 MiB
# hf-xet     ------------------------------ 1.45 MiB/2.60 MiB
# onnxruntime ------------------------------ 1.44 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 1.48 MiB/18.27 MiB
# hf-xet     ------------------------------ 1.57 MiB/2.60 MiB
# onnxruntime ------------------------------ 1.59 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 1.62 MiB/18.27 MiB
# hf-xet     ------------------------------ 1.57 MiB/2.60 MiB
# onnxruntime ------------------------------ 1.61 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 1.62 MiB/18.27 MiB
# hf-xet     ------------------------------ 1.92 MiB/2.60 MiB
# onnxruntime ------------------------------ 1.98 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 2.00 MiB/18.27 MiB
# hf-xet     ------------------------------ 2.32 MiB/2.60 MiB
# onnxruntime ------------------------------ 2.59 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 2.20 MiB/18.27 MiB
# onnxruntime ------------------------------ 2.67 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 2.52 MiB/18.27 MiB
# onnxruntime ------------------------------ 3.17 MiB/16.40 MiB
# ⠸ Preparing packages... (11/14)-- 3.28 MiB/18.27 MiB
# onnxruntime ------------------------------ 4.02 MiB/16.40 MiB
# ⠼ Preparing packages... (12/14)-- 4.02 MiB/18.27 MiB
# onnxruntime ------------------------------ 4.94 MiB/16.40 MiB
# ⠼ Preparing packages... (12/14)-- 5.17 MiB/18.27 MiB
# onnxruntime ------------------------------ 6.02 MiB/16.40 MiB
# ⠼ Preparing packages... (12/14)-- 6.28 MiB/18.27 MiB
# onnxruntime ------------------------------ 6.95 MiB/16.40 MiB
# ⠼ Preparing packages... (12/14)-- 7.36 MiB/18.27 MiB
# onnxruntime ------------------------------ 7.62 MiB/16.40 MiB
# ⠴ Preparing packages... (12/14)-- 8.02 MiB/18.27 MiB
# onnxruntime ------------------------------ 8.45 MiB/16.40 MiB
# ⠴ Preparing packages... (12/14)-- 8.98 MiB/18.27 MiB
# onnxruntime ------------------------------ 8.47 MiB/16.40 MiB
# ⠴ Preparing packages... (12/14)-- 8.98 MiB/18.27 MiB
# onnxruntime ------------------------------ 8.47 MiB/16.40 MiB
# ⠴ Preparing packages... (12/14)-- 9.00 MiB/18.27 MiB
# onnxruntime ------------------------------ 8.75 MiB/16.40 MiB
# ⠦ Preparing packages... (12/14)-- 9.23 MiB/18.27 MiB
# onnxruntime ------------------------------ 8.95 MiB/16.40 MiB
# ⠦ Preparing packages... (12/14)-- 9.47 MiB/18.27 MiB
# onnxruntime ------------------------------ 9.47 MiB/16.40 MiB
# ⠦ Preparing packages... (12/14)-- 9.58 MiB/18.27 MiB
# onnxruntime ------------------------------ 10.18 MiB/16.40 MiB
# ⠦ Preparing packages... (12/14)-- 10.25 MiB/18.27 MiB
# onnxruntime ------------------------------ 10.87 MiB/16.40 MiB
# ⠧ Preparing packages... (12/14)-- 11.25 MiB/18.27 MiB
# onnxruntime ------------------------------ 11.59 MiB/16.40 MiB
# ⠧ Preparing packages... (12/14)-- 12.22 MiB/18.27 MiB
# onnxruntime ------------------------------ 12.22 MiB/16.40 MiB
# ⠧ Preparing packages... (12/14)-- 12.93 MiB/18.27 MiB
# onnxruntime ------------------------------ 12.94 MiB/16.40 MiB
# ⠇ Preparing packages... (12/14)-- 13.64 MiB/18.27 MiB
# onnxruntime ------------------------------ 13.34 MiB/16.40 MiB
# ⠇ Preparing packages... (12/14)-- 13.64 MiB/18.27 MiB
# onnxruntime ------------------------------ 13.39 MiB/16.40 MiB
# ⠇ Preparing packages... (12/14)-- 13.64 MiB/18.27 MiB
# onnxruntime ------------------------------ 13.62 MiB/16.40 MiB
# ⠇ Preparing packages... (12/14)-- 13.67 MiB/18.27 MiB
# onnxruntime ------------------------------ 13.62 MiB/16.40 MiB
# ⠇ Preparing packages... (12/14)-- 14.23 MiB/18.27 MiB
# onnxruntime ------------------------------ 14.33 MiB/16.40 MiB
# ⠋ Preparing packages... (12/14)-- 14.98 MiB/18.27 MiB
# onnxruntime ------------------------------ 15.05 MiB/16.40 MiB
# ⠋ Preparing packages... (12/14)-- 15.59 MiB/18.27 MiB
# onnxruntime ------------------------------ 15.84 MiB/16.40 MiB
# ⠋ Preparing packages... (12/14)-- 16.36 MiB/18.27 MiB
# ⠋ Preparing packages... (12/14)m- 17.48 MiB/18.27 MiB
# Prepared 14 packages in 1.76s
# Uninstalled 1 package in 12ms
# Installed 46 packages in 222ms
#  + bcrypt==5.0.0
#  + build==1.3.0
#  + chromadb==1.3.4
#  + coloredlogs==15.0.1
#  + durationpy==0.10
#  + filelock==3.20.0
#  + flatbuffers==25.9.23
#  + fsspec==2025.10.0
#  + hf-xet==1.2.0
#  + httptools==0.7.1
#  + huggingface-hub==1.1.4
#  + humanfriendly==10.0
#  + importlib-metadata==8.7.0
#  + importlib-resources==6.5.2
#  + kubernetes==34.1.0
#  + langchain-chroma==1.0.0
#  + markdown-it-py==4.0.0
#  + mdurl==0.1.2
#  + mmh3==5.2.0
#  + mpmath==1.3.0
#  + oauthlib==3.3.1
#  + onnxruntime==1.23.2
#  + opentelemetry-api==1.38.0
#  + opentelemetry-exporter-otlp-proto-common==1.38.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
#  + opentelemetry-proto==1.38.0
#  + opentelemetry-sdk==1.38.0
#  + opentelemetry-semantic-conventions==0.59b0
#  + overrides==7.7.0
#  + posthog==5.4.0
#  + pybase64==1.4.2
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + requests-oauthlib==2.0.0
#  + rich==14.2.0
#  + shellingham==1.5.4
#  + sympy==1.14.0
#  + tokenizers==0.22.1
#  + typer==0.20.0
#  + typer-slim==0.20.0
#  - urllib3==2.5.0
#  + urllib3==2.3.0
#  + uvicorn==0.38.0
#  + uvloop==0.22.1
#  + watchfiles==1.1.1
#  + websockets==15.0.1
#  + zipp==3.23.0

# %%
from langchain_chroma import Chroma

# Create Chroma vectorstore
chroma_store = Chroma(
    collection_name="my_collection",
    embedding_function=embeddings,
    persist_directory="./chroma_db_notebook"
)

# Add documents
sample_docs = [
    Document(
        page_content="RAG combines retrieval and generation",
        metadata={"topic": "rag", "difficulty": "intermediate"}
    ),
    Document(
        page_content="LangChain simplifies LLM applications",
        metadata={"topic": "langchain", "difficulty": "beginner"}
    )
]

chroma_store.add_documents(sample_docs)
print("✅ Added documents to Chroma\n")

# Search with metadata filter
results = chroma_store.similarity_search(
    "Tell me about RAG",
    k=2,
    filter={"topic": "rag"}
)

print("Filtered search results:")
for doc in results:
    print(f"  {doc.page_content}")
    print(f"  Metadata: {doc.metadata}")
# Out:
# ✅ Added documents to Chroma
#
# Filtered search results:
#   RAG combines retrieval and generation
#   Metadata: {'difficulty': 'intermediate', 'topic': 'rag'}

# %% [markdown]
# ## 6. Vector Store Comparison
#
# | Store | Persistent | Speed | Metadata Filtering | Best For |
# |-------|-----------|-------|-------------------|----------|
# | **InMemory** | ❌ | ⚡⚡⚡ | ❌ | Testing |
# | **FAISS** | ✅ | ⚡⚡⚡ | Limited | Production, Speed |
# | **Chroma** | ✅ | ⚡⚡ | ✅ | Development, Filtering |
#
# ## Summary
#
# ✅ Vector stores enable semantic search
# ✅ InMemory for testing
# ✅ FAISS for speed and scale
# ✅ Chroma for metadata filtering
# ✅ Always persist for production!
#
# **Next:** Retrieval Strategies!
