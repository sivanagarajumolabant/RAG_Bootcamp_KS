# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.57.2
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, sentence-transformers

# %%
# !pip uninstall transformers
# Out:
# Found existing installation: transformers 4.57.2
# Uninstalling transformers-4.57.2:
#   Would remove:
#     /usr/local/bin/transformers
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.12/dist-packages/transformers-4.57.2.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/transformers/*
# Proceed (Y/n)? Y
#   Successfully uninstalled transformers-4.57.2

# %%
# !pip install transformers==4.57.1
# Out:
# Collecting transformers==4.57.1
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.1) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.1) (2025.11.12)
# Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 126.2 MB/s eta 0:00:00
# Installing collected packages: transformers
# Successfully installed transformers-4.57.1

# %%
# !pip install docling==2.55.1
# Out:
# Collecting docling==2.55.1
#   Downloading docling-2.55.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (2.12.3)
# Collecting docling-core<3.0.0,>=2.48.2 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading docling_core-2.54.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting docling-parse<5.0.0,>=4.4.0 (from docling==2.55.1)
#   Downloading docling_parse-4.7.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting docling-ibm-models<4,>=3.9.1 (from docling==2.55.1)
#   Downloading docling_ibm_models-3.10.3-py3-none-any.whl.metadata (7.3 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling==2.55.1)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2!=4.30.1,<5.0.0,>=4.30.0 (from docling==2.55.1)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (2.12.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (0.36.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (2.32.4)
# Collecting easyocr<2.0,>=1.7 (from docling==2.55.1)
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (2025.11.12)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (1.4.1)
# Collecting typer<0.20.0,>=0.12.5 (from docling==2.55.1)
#   Downloading typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling==2.55.1)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling==2.55.1)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (4.13.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (2.2.2)
# Collecting marko<3.0.0,>=2.1.2 (from docling==2.55.1)
#   Downloading marko-2.2.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (3.1.5)
# Collecting lxml<6.0.0,>=4.0.0 (from docling==2.55.1)
#   Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: pillow<12.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (11.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (4.67.1)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (1.6.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling==2.55.1)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (1.16.3)
# Requirement already satisfied: accelerate<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling==2.55.1) (1.12.0)
# Collecting polyfactory>=2.22.2 (from docling==2.55.1)
#   Downloading polyfactory-3.1.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling==2.55.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling==2.55.1) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling==2.55.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling==2.55.1) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling==2.55.1) (2.9.0+cu126)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling==2.55.1) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling==2.55.1) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling==2.55.1) (4.15.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (4.25.1)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (0.9.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading latex2mathml-3.78.1-py3-none-any.whl.metadata (15 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting tree-sitter<1.0.0,>=0.23.2 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting tree-sitter-python<1.0.0,>=0.23.6 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading tree_sitter_python-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (1.9 kB)
# Collecting tree-sitter-c<1.0.0,>=0.23.4 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tree-sitter-java<1.0.0,>=0.23.5 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading tree_sitter_java-0.23.5-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting tree-sitter-javascript<1.0.0,>=0.23.1 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.2 kB)
# Collecting tree-sitter-typescript<1.0.0,>=0.23.2 (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.12/dist-packages (from docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (4.57.1)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.12/dist-packages (from docling-ibm-models<4,>=3.9.1->docling==2.55.1) (0.24.0+cu126)
# Collecting jsonlines<5.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.9.1->docling==2.55.1)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr<2.0,>=1.7->docling==2.55.1) (4.12.0.88)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr<2.0,>=1.7->docling==2.55.1) (0.25.2)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling==2.55.1)
#   Downloading python_bidi-0.6.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr<2.0,>=1.7->docling==2.55.1) (2.1.2)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling==2.55.1)
#   Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.6 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling==2.55.1)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling==2.55.1) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling==2.55.1) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling==2.55.1) (1.2.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling==2.55.1) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling==2.55.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling==2.55.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling==2.55.1) (2025.2)
# Collecting faker>=5.0.0 (from polyfactory>=2.22.2->docling==2.55.1)
#   Downloading faker-38.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->docling==2.55.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->docling==2.55.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->docling==2.55.1) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.3.0->docling==2.55.1) (1.2.1)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling==2.55.1)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.2->docling==2.55.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.2->docling==2.55.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.2->docling==2.55.1) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.20.0,>=0.12.5->docling==2.55.1) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.20.0,>=0.12.5->docling==2.55.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.20.0,>=0.12.5->docling==2.55.1) (13.9.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines<5.0.0,>=3.1.0->docling-ibm-models<4,>=3.9.1->docling==2.55.1) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (0.29.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling==2.55.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.20.0,>=0.12.5->docling==2.55.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.20.0,>=0.12.5->docling==2.55.1) (2.19.2)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (0.22.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.55.1) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.55.1) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.55.1) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.20.0,>=0.12.5->docling==2.55.1) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate<2,>=1.0.0->docling==2.55.1) (3.0.3)
# Requirement already satisfied: multiprocess>=0.70.15 in /usr/local/lib/python3.12/dist-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (0.70.16)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling==2.55.1) (0.3.8)
# Downloading docling-2.55.1-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 17.3 MB/s eta 0:00:00
# Downloading docling_core-2.54.0-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 kB 18.7 MB/s eta 0:00:00
# Downloading docling_ibm_models-3.10.3-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 8.8 MB/s eta 0:00:00
# Downloading docling_parse-4.7.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 132.5 MB/s eta 0:00:00
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 100.9 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 137.5 MB/s eta 0:00:00
# Downloading marko-2.2.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.1 MB/s eta 0:00:00
# Downloading polyfactory-3.1.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 5.8 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 68.5 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 22.8 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 38.1 MB/s eta 0:00:00
# Downloading typer-0.19.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.4 MB/s eta 0:00:00
# Downloading faker-38.2.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.2 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading latex2mathml-3.78.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 7.0 MB/s eta 0:00:00
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (635 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 41.4 MB/s eta 0:00:00
# Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 10.0 MB/s eta 0:00:00
# Downloading tree_sitter_java-0.23.5-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.6 MB/s eta 0:00:00
# Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 10.1 MB/s eta 0:00:00
# Downloading tree_sitter_python-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 10.1 MB/s eta 0:00:00
# Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.0/345.0 kB 31.4 MB/s eta 0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 15.6 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 17.3 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 51.8 MB/s eta 0:00:00
# Downloading python_bidi-0.6.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 26.1 MB/s eta 0:00:00
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 17.4 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=f91bf5bd99f460cec27fb85dc333f963d9c9a127d5877618bd60a4a22932ff35
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: python-bidi, pylatexenc, filetype, XlsxWriter, tree-sitter-typescript, tree-sitter-python, tree-sitter-javascript, tree-sitter-java, tree-sitter-c, tree-sitter, pypdfium2, pyclipper, ninja, mpire, marko, lxml, latex2mathml, jsonref, jsonlines, faker, python-pptx, python-docx, polyfactory, typer, semchunk, docling-core, easyocr, docling-parse, docling-ibm-models, docling
#   Attempting uninstall: lxml
#     Found existing installation: lxml 6.0.2
#     Uninstalling lxml-6.0.2:
#       Successfully uninstalled lxml-6.0.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.20.0
#     Uninstalling typer-0.20.0:
#       Successfully uninstalled typer-0.20.0
# Successfully installed XlsxWriter-3.2.9 docling-2.55.1 docling-core-2.54.0 docling-ibm-models-3.10.3 docling-parse-4.7.2 easyocr-1.7.2 faker-38.2.0 filetype-1.2.0 jsonlines-4.0.0 jsonref-1.1.0 latex2mathml-3.78.1 lxml-5.4.0 marko-2.2.1 mpire-2.10.2 ninja-1.13.0 polyfactory-3.1.0 pyclipper-1.4.0 pylatexenc-2.10 pypdfium2-4.30.0 python-bidi-0.6.7 python-docx-1.2.0 python-pptx-1.0.2 semchunk-2.2.2 tree-sitter-0.25.2 tree-sitter-c-0.24.1 tree-sitter-java-0.23.5 tree-sitter-javascript-0.25.0 tree-sitter-python-0.25.0 tree-sitter-typescript-0.23.2 typer-0.19.2

# %%
# !pip install openai-whisper
# Out:
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 29.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (4.67.1)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (3.5.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.11.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper) (3.0.3)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=c7e8c7c16f66c3cba365785fbbfe8ff8728ef1ef22c04508799470f0aad77415
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20250625

# %%
# Audio transcription example (requires 'asr' extra)
from docling.document_converter import DocumentConverter, AudioFormatOption
from docling.datamodel.base_models import InputFormat
from docling.pipeline.asr_pipeline import AsrPipeline
from docling.datamodel.pipeline_options import AsrPipelineOptions
from docling.datamodel import asr_model_specs

print("Audio Transcription (ASR) Pattern:")
print("-" * 40)


# Configure ASR pipeline
asr_options = AsrPipelineOptions(
    asr_options=asr_model_specs.WHISPER_BASE,  # or WHISPER_BASE, WHISPER_SMALL
)

converter = DocumentConverter(
    format_options={
        InputFormat.AUDIO: AudioFormatOption(
            pipeline_cls=AsrPipeline,
            pipeline_options=asr_options,
        )
    }
)

result = converter.convert("/content/Agentic AI Bootcamp With No Code Tools n8n Udemy Course Announcement.mp3")  # or .wav
transcript = result.document.export_to_markdown()
print(transcript)
print("\nSupported formats: WAV, MP3")
#print("Requires: pip install 'docling[asr]'")
# Out:
# Audio Transcription (ASR) Pattern:
# ----------------------------------------
# 100%|████████████████████████████████████████| 139M/139M [00:00<00:00, 272MiB/s]
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:03.640]  Hello, all my name is Krish Nayak and welcome to my YouTube channel.
# [00:03.860 --> 00:08.320]  So guys, I am super excited to announce a new UDEMY course.
# [00:08.760 --> 00:16.320]  That is complete AI automation and agentic AI bootcamp with no code tool that is NITN.
# [00:17.120 --> 00:22.900]  Now this was one of the most requested course by many many people from freshers, to experience
# [00:22.900 --> 00:28.600]  professionals, to from people from coding background, non coding background, Genie I leaders,
# [00:28.600 --> 00:33.240]  many people were actually requesting this specific course and we took somewhere around
# [00:33.240 --> 00:39.220]  one and a half months to probably do the entire research, record the entire videos and
# [00:39.220 --> 00:44.740]  build some amazing end-to-end projects and this project's till the deployment part is
# [00:44.740 --> 00:47.460]  actually covered, all the things is basically covered over here.
# [00:48.180 --> 00:53.180]  So we will be focusing on how you can build AI driven automation, agentic AI workflows
# [00:53.180 --> 00:54.620]  with NITN, right?
# [00:55.120 --> 01:00.320]  NITN is also becoming one of the most popular no coding platforms to build this kind of workflows.
# [01:00.920 --> 01:06.780]  Okay, this course is recorded by Mank, let me talk about Mank, he's a very experienced
# [01:06.780 --> 01:13.160]  professional who gives corporate trainings, who helps industries companies to build this
# [01:13.160 --> 01:15.580]  kind of workflows with the help of NITN itself.
# [01:15.880 --> 01:20.680]  He has given many many corporate trainings, amazing feedback from everyone out there, right?
# [01:20.680 --> 01:24.980]  And then here you'll be learning all these things that is building AI automation workflow
# [01:24.980 --> 01:29.980]  using NITN, integrate LLM from intelligent actions, create agentic AI systems that
# [01:29.980 --> 01:36.300]  autonomously analyze, design and execute tasks, connect NITN with API databases, apps to
# [01:36.300 --> 01:40.740]  build end-to-end AI pipelines and here you can also see that deploying monitoring, scaling
# [01:40.740 --> 01:43.420]  AI driven workflows for production-ready automation.
# [01:44.020 --> 01:49.340]  So this way you will be quickly able to develop any kind of workflows with respect to any
# [01:49.340 --> 01:50.540]  ideation that you have.
# [01:50.980 --> 01:56.140]  This is one of the most important skillset that is required right now because as soon as
# [01:56.140 --> 02:00.520]  you get a specific idea it is always good to start with a POC project and there you can
# [02:00.520 --> 02:02.040]  use no code tools like NITN.
# [02:02.340 --> 02:06.960]  And NITN has been used by many companies out there because now with the help of this
# [02:06.960 --> 02:13.000]  you are able to build some amazing end-to-end projects directly, you are able to deploy
# [02:13.000 --> 02:15.120]  your workflows directly into the cloud, right?
# [02:16.120 --> 02:21.140]  This entire course is somewhere around 18 hours and we will keep on getting updated as
# [02:21.140 --> 02:23.640]  we put up more projects in this particular course, right?
# [02:24.060 --> 02:27.960]  So here you can see introduction, introduction to AI automation and NITN foundation.
# [02:28.360 --> 02:33.120]  We go ahead and do the installation setup and interfaces, concepts, nodes, you know,
# [02:33.480 --> 02:40.320]  automation with NITN, JSON with NITN, you can see API with NITN, AI in automation, agents
# [02:40.320 --> 02:40.880]  in automation.
# [02:41.720 --> 02:46.700]  Here you can see pros, social media automation, GitHub PR automation agent, so many different,
# [02:46.780 --> 02:51.620]  different amazing topics, you know, from chain of thoughts to agents, parallel workflow,
# [02:51.940 --> 02:57.460]  controller router agent, react agent where you don't have to do coding with the help of
# [02:57.460 --> 03:01.200]  the no-coding tool that is NITN will be implementing all these things.
# [03:01.320 --> 03:06.480]  Yes, we can also use other coding frameworks like Lanchion, Lanchion, Lanchion, do this,
# [03:06.620 --> 03:09.120]  that for that I have created a separate course in NewDame, right?
# [03:09.820 --> 03:16.340]  And here you can see model context protocol, MCP in NITN Cloud, running NITN on local and
# [03:16.340 --> 03:21.780]  self hosted cloud, RAG, everything is basically covered, you know, we have also used different
# [03:21.780 --> 03:26.780]  kind of vector databases like Pinecone, then you also have something called as NITN,
# [03:27.040 --> 03:32.300]  self hosting kit, you know, then we have also built some projects, amazing projects,
# [03:32.520 --> 03:36.960]  N2N projects, these projects you can see like how like WhatsApp agent, video creation with
# [03:36.960 --> 03:40.480]  Germany and we are updating more projects as we go ahead, right?
# [03:40.940 --> 03:45.440]  So all these things have been covered in very much amazing way, the price of the course
# [03:45.440 --> 03:50.880]  is just 399, for people who are outside India, somewhere around 9.99 dollars, it depends
# [03:51.580 --> 03:57.140]  where you are basically situated, but this is the price just imagine with the small amount
# [03:57.140 --> 04:01.500]  of money you are able to get the entire content related to NITN, isn't it amazing?
# [04:02.140 --> 04:07.120]  We are focusing more on affordability, we are making sure that we build some amazing courses
# [04:07.120 --> 04:13.860]  for you. Recently we have also launched this complete MCP bootcamp over here, you can also see
# [04:13.860 --> 04:18.420]  that everything is hot and new, hot and new, we are getting some good amazing readings from
# [04:18.420 --> 04:23.180]  every one, you know, and we have covered each and everything from real world projects, N2N
# [04:23.180 --> 04:26.680]  projects in the all. And if you just search for crocheted technologies, here you'll be able to
# [04:26.680 --> 04:31.400]  see more courses, right? We are making sure that we build all these particular courses, add more
# [04:31.400 --> 04:36.860]  values to all of you, right? So I hope you like this particular video. One more very important
# [04:36.860 --> 04:42.900]  thing is that I'm very happy to announce that we have reached 187 countries, you know, so we
# [04:43.480 --> 04:50.480]  how courses have been now being used by people from 187 countries in 54 different languages,
# [04:50.740 --> 04:55.240]  at least in the form of caption, India is the highest segment, then we have US, Canada,
# [04:55.240 --> 05:02.500]  European countries, African countries, South American countries, they are definitely using it.
# [05:02.920 --> 05:07.180]  So this is the value that we are providing by providing affordability in this. So my
# [05:07.180 --> 05:12.940]  request to be that support affordability, focus on learning amazing things, start building things
# [05:13.480 --> 05:18.520]  and keep on applying, keep on applying your skillsets to make a life better in terms of salary,
# [05:18.780 --> 05:23.080]  work life balance and many more things. So I hope you like this particular video, right now this
# [05:23.080 --> 05:26.440]  particular course information will be given in the description on this particular video, go ahead,
# [05:26.580 --> 05:30.040]  explore it and I'll see you in the next video, have a great day, thank you and I'll take care, bye bye.
# [time: 0.0-3.64]  Hello, all my name is Krish Nayak and welcome to my YouTube channel.
#
# [time: 3.86-8.32]  So guys, I am super excited to announce a new UDEMY course.
#
# [time: 8.76-16.32]  That is complete AI automation and agentic AI bootcamp with no code tool that is NITN.
#
# [time: 17.12-22.9]  Now this was one of the most requested course by many many people from freshers, to experience
#
# [time: 22.9-28.6]  professionals, to from people from coding background, non coding background, Genie I leaders,
#
# [time: 28.6-33.24]  many people were actually requesting this specific course and we took somewhere around
#
# [time: 33.24-39.22]  one and a half months to probably do the entire research, record the entire videos and
#
# [time: 39.22-44.74]  build some amazing end-to-end projects and this project's till the deployment part is
#
# [time: 44.74-47.46]  actually covered, all the things is basically covered over here.
#
# [time: 48.18-53.18]  So we will be focusing on how you can build AI driven automation, agentic AI workflows
#
# [time: 53.18-54.62]  with NITN, right?
#
# [time: 55.12-60.32]  NITN is also becoming one of the most popular no coding platforms to build this kind of workflows.
#
# [time: 60.92-66.78]  Okay, this course is recorded by Mank, let me talk about Mank, he's a very experienced
#
# [time: 66.78-73.16]  professional who gives corporate trainings, who helps industries companies to build this
#
# [time: 73.16-75.58]  kind of workflows with the help of NITN itself.
#
# [time: 75.88-80.68]  He has given many many corporate trainings, amazing feedback from everyone out there, right?
#
# [time: 80.68-84.98]  And then here you'll be learning all these things that is building AI automation workflow
#
# [time: 84.98-89.98]  using NITN, integrate LLM from intelligent actions, create agentic AI systems that
#
# [time: 89.98-96.3]  autonomously analyze, design and execute tasks, connect NITN with API databases, apps to
#
# [time: 96.3-100.74]  build end-to-end AI pipelines and here you can also see that deploying monitoring, scaling
#
# [time: 100.74-103.42]  AI driven workflows for production-ready automation.
#
# [time: 104.02-109.34]  So this way you will be quickly able to develop any kind of workflows with respect to any
#
# [time: 109.34-110.54]  ideation that you have.
#
# [time: 110.98-116.14]  This is one of the most important skillset that is required right now because as soon as
#
# [time: 116.14-120.52]  you get a specific idea it is always good to start with a POC project and there you can
#
# [time: 120.52-122.04]  use no code tools like NITN.
#
# [time: 122.34-126.96]  And NITN has been used by many companies out there because now with the help of this
#
# [time: 126.96-133.0]  you are able to build some amazing end-to-end projects directly, you are able to deploy
#
# [time: 133.0-135.12]  your workflows directly into the cloud, right?
#
# [time: 136.12-141.14]  This entire course is somewhere around 18 hours and we will keep on getting updated as
#
# [time: 141.14-143.64]  we put up more projects in this particular course, right?
#
# [time: 144.06-147.96]  So here you can see introduction, introduction to AI automation and NITN foundation.
#
# [time: 148.36-153.12]  We go ahead and do the installation setup and interfaces, concepts, nodes, you know,
#
# [time: 153.48-160.32]  automation with NITN, JSON with NITN, you can see API with NITN, AI in automation, agents
#
# [time: 160.32-160.88]  in automation.
#
# [time: 161.72-166.7]  Here you can see pros, social media automation, GitHub PR automation agent, so many different,
#
# [time: 166.78-171.62]  different amazing topics, you know, from chain of thoughts to agents, parallel workflow,
#
# [time: 171.94-177.46]  controller router agent, react agent where you don't have to do coding with the help of
#
# [time: 177.46-181.2]  the no-coding tool that is NITN will be implementing all these things.
#
# [time: 181.32-186.48]  Yes, we can also use other coding frameworks like Lanchion, Lanchion, Lanchion, do this,
#
# [time: 186.62-189.12]  that for that I have created a separate course in NewDame, right?
#
# [time: 189.82-196.34]  And here you can see model context protocol, MCP in NITN Cloud, running NITN on local and
#
# [time: 196.34-201.78]  self hosted cloud, RAG, everything is basically covered, you know, we have also used different
#
# [time: 201.78-206.78]  kind of vector databases like Pinecone, then you also have something called as NITN,
#
# [time: 207.04-212.3]  self hosting kit, you know, then we have also built some projects, amazing projects,
#
# [time: 212.52-216.96]  N2N projects, these projects you can see like how like WhatsApp agent, video creation with
#
# [time: 216.96-220.48]  Germany and we are updating more projects as we go ahead, right?
#
# [time: 220.94-225.44]  So all these things have been covered in very much amazing way, the price of the course
#
# [time: 225.44-230.88]  is just 399, for people who are outside India, somewhere around 9.99 dollars, it depends
#
# [time: 231.58-237.14]  where you are basically situated, but this is the price just imagine with the small amount
#
# [time: 237.14-241.5]  of money you are able to get the entire content related to NITN, isn't it amazing?
#
# [time: 242.14-247.12]  We are focusing more on affordability, we are making sure that we build some amazing courses
#
# [time: 247.12-253.86]  for you. Recently we have also launched this complete MCP bootcamp over here, you can also see
#
# [time: 253.86-258.42]  that everything is hot and new, hot and new, we are getting some good amazing readings from
#
# [time: 258.42-263.18]  every one, you know, and we have covered each and everything from real world projects, N2N
#
# [time: 263.18-266.68]  projects in the all. And if you just search for crocheted technologies, here you'll be able to
#
# [time: 266.68-271.4]  see more courses, right? We are making sure that we build all these particular courses, add more
#
# [time: 271.4-276.86]  values to all of you, right? So I hope you like this particular video. One more very important
#
# [time: 276.86-282.9]  thing is that I'm very happy to announce that we have reached 187 countries, you know, so we
#
# [time: 283.47999999999996-290.48]  how courses have been now being used by people from 187 countries in 54 different languages,
#
# [time: 290.74-295.24]  at least in the form of caption, India is the highest segment, then we have US, Canada,
#
# [time: 295.24-302.5]  European countries, African countries, South American countries, they are definitely using it.
#
# [time: 302.92-307.18]  So this is the value that we are providing by providing affordability in this. So my
#
# [time: 307.18-312.94]  request to be that support affordability, focus on learning amazing things, start building things
#
# [time: 313.48-318.52]  and keep on applying, keep on applying your skillsets to make a life better in terms of salary,
#
# [time: 318.78-323.08]  work life balance and many more things. So I hope you like this particular video, right now this
#
# [time: 323.08-326.44]  particular course information will be given in the description on this particular video, go ahead,
#
# [time: 326.58-330.04]  explore it and I'll see you in the next video, have a great day, thank you and I'll take care, bye bye.
#
# Supported formats: WAV, MP3

# %% [markdown]
# # VLM

# %%
# VLM Pipeline Configuration
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.pipeline.vlm_pipeline import VlmPipeline
from docling.datamodel import vlm_model_specs
from docling.datamodel.pipeline_options import VlmPipelineOptions

print("VLM Pipeline Configuration:")
print("=" * 60)

# Option 1: GraniteDocling with Transformers (cross-platform)
print("\n1. GraniteDocling with Transformers (GPU/CPU):")
print("-" * 40)
pipeline_options = VlmPipelineOptions(
    vlm_options=vlm_model_specs.GRANITEDOCLING_TRANSFORMERS,
)

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_cls=VlmPipeline,
            pipeline_options=pipeline_options,
        ),
    }
)

# Convert with VLM
pdf_url="https://arxiv.org/pdf/2408.09869"
result = converter.convert(pdf_url)
vlm_markdown = result.document.export_to_markdown()
print(vlm_markdown[:2000])
# Out:
# VLM Pipeline Configuration:
# ============================================================
#
# 1. GraniteDocling with Transformers (GPU/CPU):
# ----------------------------------------
# <!-- image -->
#
# ## Docling Technical Report
#
# Version 1.0
#
# Christoph Auer Maksym Lysak Ahmed Nassar Michele Dolfi Nikolaos Livathinos Pasaro Vagenas Cesar Berrospi Ramis Matteo Omenetti Fabian Lindlbaer Kasper Dikka Lokesh Mishra Yusik Kimsh Shubham Gupta Rafael Teixeira de Lima Valery Weber Lucas Morin Ingmar Meijer Viktor Kuropiatnyk Peter W. J. Staar
#
# AI4K Group, IBM Research
#
# Rüschlikon, Switzerland
#
# This technical report introduces Doclinng an easy to use, self-contained, MI-TT-licensed open-source package for PDF document conversion. It is powered by static-of-the-art specialized AI models for layout analysis (DocLayNet) and tabl e structure recognition (TableFormer), and runs efficiently on commodity hardware in small resource budget. The code includes interface allows for easy extensibility and addition of new features and models.
#
# ## 1 Introduction
#
# Converting PDF documents back into a machine-processable format has been a major challenge for decades due to their huge variab le in formats, weak standardization and printing-optimized characteristics, which discards most structural features and metadata. With the advent of LLMs and popular application patterns such as retrieval-augmented generation (RAG), leveraging the rich content embedded in PDFs has become ever more relevant. In the past decade, several powerful document understanding solutions have emerged on the market, most of which are commercial software, such as docling and docling-v3.
#
# With Docli ng, we open-source a very capable and efficient document conversion tool which builds on the powerful AI models for layout analysis (DocLayNet) and tabl e structure recognition (TableFormer), and runs efficiently on commodity hardware in small resource budget. The code includes interface allows for easy extensibility and addition of new features and models.
#
# Here is what Docling delivers today:
#
# - · Converts PDF documents to JSON or Markdown format, stable and lightning fast
# - · Understands detailed page la

# %%
# VLM Pipeline - Live Example (requires significant GPU/memory)
# Uncomment to run if you have sufficient resources

from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.pipeline.vlm_pipeline import VlmPipeline
from docling.datamodel import vlm_model_specs
from docling.datamodel.pipeline_options import VlmPipelineOptions

# Configure VLM pipeline
pipeline_options = VlmPipelineOptions(
    vlm_options=vlm_model_specs.GRANITEDOCLING_TRANSFORMERS,
)

vlm_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_cls=VlmPipeline,
            pipeline_options=pipeline_options,
        ),
    }
)

# Convert with VLM
result = vlm_converter.convert(pdf_url)
vlm_markdown = result.document.export_to_markdown()
print(vlm_markdown[:2000])

print("VLM example is commented out to avoid resource issues.")
print("Uncomment and run if you have GPU/sufficient memory.")
# Out:
# <!-- image -->
#
# ## Docling Technical Report
#
# Version 1.0
#
# Christoph Auer Maksym Lysak Ahmed Nassar Michele Dolfi Nikolaos Livathinos Pasaro Vagenas Cesar Berrospi Ramis Matteo Omenetti Fabian Lindlbaer Kasper Dikka Lokesh Mishra Yusik Kimsh Shubham Gupta Rafael Teixeira de Lima Valery Weber Lucas Morin Ingmar Meijer Viktor Kuropiatnyk Peter W. J. Staar
#
# AI4K Group, IBM Research
#
# Rüschlikon, Switzerland
#
# This technical report introduces Doclinng an easy to use, self-contained, MI-TT-licensed open-source package for PDF document conversion. It is powered by static-of-the-art specialized AI models for layout analysis (DocLayNet) and tabl e structure recognition (TableFormer), and runs efficiently on commodity hardware in small resource budget. The code includes interface allows for easy extensibility and addition of new features and models.
#
# ## 1 Introduction
#
# Converting PDF documents back into a machine-processable format has been a major challenge for decades due to their huge variab le in formats, weak standardization and printing-optimized characteristics, which discards most structural features and metadata. With the advent of LLMs and popular application patterns such as retrieval-augmented generation (RAG), leveraging the rich content embedded in PDFs has become ever more relevant. In the past decade, several powerful document understanding solutions have emerged on the market, most of which are commercial software, such as docling and docling-v3.
#
# With Docli ng, we open-source a very capable and efficient document conversion tool which builds on the powerful AI models for layout analysis (DocLayNet) and tabl e structure recognition (TableFormer), and runs efficiently on commodity hardware in small resource budget. The code includes interface allows for easy extensibility and addition of new features and models.
#
# Here is what Docling delivers today:
#
# - · Converts PDF documents to JSON or Markdown format, stable and lightning fast
# - · Understands detailed page la
# VLM example is commented out to avoid resource issues.
# Uncomment and run if you have GPU/sufficient memory.

# %%
#Option 2: GraniteDocling MLX (Apple Silicon optimized)

print("\n2. GraniteDocling MLX (Apple Silicon M1/M2/M3/M4):")
print("-" * 40)
pipeline_options = VlmPipelineOptions(
    vlm_options=vlm_model_specs.GRANITEDOCLING_MLX,
)

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_cls=VlmPipeline,
            pipeline_options=pipeline_options,
        ),
    }
)
# Convert with VLM
pdf_url="https://arxiv.org/pdf/2408.09869"
result = vlm_converter.convert(pdf_url)
vlm_markdown = result.document.export_to_markdown()
print(vlm_markdown[:2000])
# Out:
# 2. GraniteDocling MLX (Apple Silicon M1/M2/M3/M4):
# ----------------------------------------
# <!-- image -->
#
# ## Docling Technical Report
#
# Version 1.0
#
# Christoph Auer Maksym Lysak Ahmed Nassar Michele Dolfi Nikolaos Livathinos Pasaro Vagenas Cesar Berrospi Ramis Matteo Omenetti Fabian Lindlbaer Kasper Dikka Lokesh Mishra Yusik Kimsh Shubham Gupta Rafael Teixeira de Lima Valery Weber Lucas Morin Ingmar Meijer Viktor Kuropiatnyk Peter W. J. Staar
#
# AI4K Group, IBM Research
#
# Rüschlikon, Switzerland
#
# This technical report introduces Doclinng an easy to use, self-contained, MI-TT-licensed open-source package for PDF document conversion. It is powered by static-of-the-art specialized AI models for layout analysis (DocLayNet) and tabl e structure recognition (TableFormer), and runs efficiently on commodity hardware in small resource budget. The code includes interface allows for easy extensibility and addition of new features and models.
#
# ## 1 Introduction
#
# Converting PDF documents back into a machine-processable format has been a major challenge for decades due to their huge variab le in formats, weak standardization and printing-optimized characteristics, which discards most structural features and metadata. With the advent of LLMs and popular application patterns such as retrieval-augmented generation (RAG), leveraging the rich content embedded in PDFs has become ever more relevant. In the past decade, several powerful document understanding solutions have emerged on the market, most of which are commercial software, such as docling and docling-v3.
#
# With Docli ng, we open-source a very capable and efficient document conversion tool which builds on the powerful AI models for layout analysis (DocLayNet) and tabl e structure recognition (TableFormer), and runs efficiently on commodity hardware in small resource budget. The code includes interface allows for easy extensibility and addition of new features and models.
#
# Here is what Docling delivers today:
#
# - · Converts PDF documents to JSON or Markdown format, stable and lightning fast
# - · Understands detailed page la
